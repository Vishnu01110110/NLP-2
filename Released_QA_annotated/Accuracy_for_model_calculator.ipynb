# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import string
import re
from collections import Counter

prediction_f = '/content/drive/MyDrive/CMU_FALL2024/11711_ANLP/HW2_ANLP/FinalModelEval/RELEASED_QA_MODEL_OUTPUT.txt'
reference_f = '/content/drive/MyDrive/CMU_FALL2024/11711_ANLP/HW2_ANLP/FinalModelEval/RELEASED_QA_ANSWERS.txt'

# Function to normalize text (removes punctuation, articles, etc.)
def normalize_answer(s):
    def remove_articles(text):
        return re.sub(r'\b(a|an|the)\b', ' ', text)

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punctuation(text):
        return ''.join(ch for ch in text if ch not in set(string.punctuation))

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punctuation(lower(s))))

# Function to calculate F1 score
def f1_score(prediction, ground_truth):
    prediction_tokens = normalize_answer(prediction).split()
    ground_truth_tokens = normalize_answer(ground_truth).split()
    common = Counter(prediction_tokens) & Counter(ground_truth_tokens)
    num_same = sum(common.values())

    if num_same == 0:
        return 0

    precision = num_same / len(prediction_tokens)
    recall = num_same / len(ground_truth_tokens)
    f1 = 2 * precision * recall / (precision + recall)

    return f1

# Function to calculate exact match
def exact_match_score(prediction, ground_truth):
    return normalize_answer(prediction) == normalize_answer(ground_truth)

# Function to calculate recall
def recall_score(prediction, ground_truth):
    prediction_tokens = normalize_answer(prediction).split()
    ground_truth_tokens = normalize_answer(ground_truth).split()
    common = Counter(prediction_tokens) & Counter(ground_truth_tokens)
    num_same = sum(common.values())

    if len(ground_truth_tokens) == 0:
        return 0

    recall = num_same / len(ground_truth_tokens)
    return recall

question_scores = []
# Updated evaluate function to include recall
def evaluate_with_recall(predictions, references):
    total = len(references)
    f1 = exact_match = recall = 0
    question_num = 1

    for pred, ref in zip(predictions, references):
        exact_match_dif = exact_match_score(pred, ref)
        f1_dif = f1_score(pred, ref)
        recall_dif = recall_score(pred, ref)

        question_scores.append((1, "Question: ", question_num, " scores are -> ", 'exact_match: ', exact_match_dif, ' f1: ', f1_dif, ' recall: ', recall_dif))
        question_num += 1

        exact_match += exact_match_dif
        f1 += f1_dif
        recall += recall_dif

    exact_match = 100.0 * exact_match / total
    f1 = 100.0 * f1 / total
    recall = 100.0 * recall / total

    return {'exact_match': exact_match, 'f1': f1, 'recall': recall}

def evaluate(prediction_file=prediction_f):
    # Example usage
    predictions = []
    references = []
    # Read references file
    with open(reference_f, 'r') as f:
        references = f.readlines()

    # Read predictions file
    with open(prediction_file, 'r') as f:
        predictions = f.readlines()


    # the first 100 is event, the second 100 is general info, the third 100 is sports, the fourth 100 is music and culture

    # Evaluate the first 100 questions
    results = evaluate_with_recall(predictions, references)
    print('Accuracy: ')
    print(results)

# Rag model
print("---RAG model accuracy on released test data---")
evaluate(prediction_f)
for elem in question_scores:
  print(elem)
# Out:
# ---RAG model accuracy on released test data---
# Accuracy:
# {'exact_match': 9.24731182795699, 'f1': 18.64688227426668, 'recall': 19.025293105938275}
# (1, 'Question: ', 1, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.4, ' recall: ', 0.5)
# (1, 'Question: ', 2, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 3, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 4, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 5, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.6666666666666666, ' recall: ', 0.5)
# (1, 'Question: ', 6, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 7, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.9090909090909091, ' recall: ', 0.8333333333333334)
# (1, 'Question: ', 8, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 9, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 10, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 11, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 12, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 13, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.8, ' recall: ', 0.6666666666666666)
# (1, 'Question: ', 14, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 15, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 16, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 17, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5, ' recall: ', 0.5)
# (1, 'Question: ', 18, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 19, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 20, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 21, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.6666666666666666, ' recall: ', 1.0)
# (1, 'Question: ', 22, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 23, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5, ' recall: ', 0.8333333333333334)
# (1, 'Question: ', 24, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.8, ' recall: ', 0.6666666666666666)
# (1, 'Question: ', 25, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 26, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5, ' recall: ', 1.0)
# (1, 'Question: ', 27, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 28, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.22222222222222224, ' recall: ', 0.5)
# (1, 'Question: ', 29, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 30, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 31, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 32, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 33, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 34, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 35, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 36, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 37, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 38, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 39, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 40, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 41, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 42, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 43, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 44, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 45, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.22222222222222224, ' recall: ', 0.25)
# (1, 'Question: ', 46, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.2857142857142857, ' recall: ', 0.16666666666666666)
# (1, 'Question: ', 47, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.13333333333333333, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 48, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 49, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 50, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 51, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 52, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 53, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.4444444444444444, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 54, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 55, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 56, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 57, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.11764705882352941, ' recall: ', 0.2)
# (1, 'Question: ', 58, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 59, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 60, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 61, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 62, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.4, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 63, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.3333333333333333, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 64, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 65, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 66, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.4545454545454545, ' recall: ', 0.7142857142857143)
# (1, 'Question: ', 67, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.2, ' recall: ', 0.4)
# (1, 'Question: ', 68, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 69, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.3333333333333333, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 70, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 71, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.15384615384615383, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 72, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 73, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 74, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 75, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 76, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 77, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 78, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 79, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 80, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 81, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 82, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 83, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 84, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 85, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 86, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 87, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.2857142857142857, ' recall: ', 0.16666666666666666)
# (1, 'Question: ', 88, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 89, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 90, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 91, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.8333333333333333, ' recall: ', 1.0)
# (1, 'Question: ', 92, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.3076923076923077, ' recall: ', 0.4)
# (1, 'Question: ', 93, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 94, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 95, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.6666666666666666, ' recall: ', 0.5)
# (1, 'Question: ', 96, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.8, ' recall: ', 0.6666666666666666)
# (1, 'Question: ', 97, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 98, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 99, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 100, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.3333333333333333, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 101, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 102, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 103, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 104, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 105, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 106, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 107, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 108, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.6666666666666666, ' recall: ', 0.6666666666666666)
# (1, 'Question: ', 109, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 110, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 111, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 112, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 113, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 114, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.3333333333333333, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 115, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 116, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.3333333333333333, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 117, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 118, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 119, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 120, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.28571428571428575, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 121, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 122, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 123, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.2222222222222222, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 124, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.14285714285714288, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 125, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.8333333333333333, ' recall: ', 1.0)
# (1, 'Question: ', 126, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 127, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 128, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 129, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5, ' recall: ', 0.5)
# (1, 'Question: ', 130, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 131, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 132, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 133, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 134, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 135, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 136, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 137, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 138, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 139, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 140, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5, ' recall: ', 0.5)
# (1, 'Question: ', 141, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 142, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.3333333333333333, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 143, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 144, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 145, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 146, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 147, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 148, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.2222222222222222, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 149, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.28571428571428575, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 150, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 151, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 152, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 153, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 154, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 155, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5714285714285715, ' recall: ', 1.0)
# (1, 'Question: ', 156, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 157, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 158, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 159, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.4, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 160, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 161, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 162, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 163, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 164, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 165, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 166, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 167, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 168, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.6666666666666666, ' recall: ', 1.0)
# (1, 'Question: ', 169, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 170, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 171, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 172, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 173, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 174, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 175, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5, ' recall: ', 0.5)
# (1, 'Question: ', 176, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 177, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 178, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 179, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 180, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 181, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 182, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 183, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.8, ' recall: ', 0.6666666666666666)
# (1, 'Question: ', 184, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 185, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 186, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.16666666666666669, ' recall: ', 1.0)
# (1, 'Question: ', 187, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 188, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 189, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 190, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 191, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 192, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 193, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 194, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.4, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 195, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 196, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.75, ' recall: ', 0.75)
# (1, 'Question: ', 197, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.8571428571428571, ' recall: ', 0.75)
# (1, 'Question: ', 198, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 199, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.28571428571428575, ' recall: ', 0.25)
# (1, 'Question: ', 200, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 201, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 202, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 203, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 204, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 205, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 206, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.22222222222222224, ' recall: ', 0.2)
# (1, 'Question: ', 207, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 208, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 209, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 210, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 211, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.6666666666666665, ' recall: ', 0.6)
# (1, 'Question: ', 212, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 213, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.4, ' recall: ', 0.5)
# (1, 'Question: ', 214, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 215, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 216, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.4, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 217, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 218, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 219, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 220, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 221, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 222, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 223, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.13333333333333333, ' recall: ', 0.25)
# (1, 'Question: ', 224, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 225, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.25, ' recall: ', 0.14285714285714285)
# (1, 'Question: ', 226, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.4, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 227, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 228, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.4, ' recall: ', 0.25)
# (1, 'Question: ', 229, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 230, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 231, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 232, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.4, ' recall: ', 0.5)
# (1, 'Question: ', 233, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 234, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 235, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 236, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 237, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 238, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 239, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.09523809523809525, ' recall: ', 0.1)
# (1, 'Question: ', 240, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 241, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 242, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 243, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.3333333333333333, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 244, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.08333333333333334, ' recall: ', 0.1111111111111111)
# (1, 'Question: ', 245, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 246, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.2, ' recall: ', 0.16666666666666666)
# (1, 'Question: ', 247, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.33333333333333337, ' recall: ', 0.2)
# (1, 'Question: ', 248, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 249, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 250, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 251, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.2222222222222222, ' recall: ', 0.125)
# (1, 'Question: ', 252, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 253, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 254, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5, ' recall: ', 0.6666666666666666)
# (1, 'Question: ', 255, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 256, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.4615384615384615, ' recall: ', 0.6)
# (1, 'Question: ', 257, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 258, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 259, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.42857142857142855, ' recall: ', 0.42857142857142855)
# (1, 'Question: ', 260, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 261, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 262, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 263, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 264, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5, ' recall: ', 0.5)
# (1, 'Question: ', 265, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.10526315789473685, ' recall: ', 0.14285714285714285)
# (1, 'Question: ', 266, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.33333333333333337, ' recall: ', 0.2)
# (1, 'Question: ', 267, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 268, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.8, ' recall: ', 0.6666666666666666)
# (1, 'Question: ', 269, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 270, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 271, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.3529411764705882, ' recall: ', 0.5)
# (1, 'Question: ', 272, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 273, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 274, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 275, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 276, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 277, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 278, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 279, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 280, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.6666666666666666, ' recall: ', 0.5)
# (1, 'Question: ', 281, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.09523809523809523, ' recall: ', 0.14285714285714285)
# (1, 'Question: ', 282, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 283, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 284, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 285, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.28571428571428575, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 286, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 287, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.6666666666666666, ' recall: ', 0.5)
# (1, 'Question: ', 288, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 289, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 290, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 291, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.25, ' recall: ', 0.25)
# (1, 'Question: ', 292, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 293, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 294, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 295, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 296, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 297, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 298, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.36363636363636365, ' recall: ', 0.2857142857142857)
# (1, 'Question: ', 299, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 300, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 301, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 302, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.6666666666666666, ' recall: ', 0.6666666666666666)
# (1, 'Question: ', 303, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 304, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 305, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.4, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 306, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 307, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 308, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.3333333333333333, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 309, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 310, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 311, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 312, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 313, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.13333333333333333, ' recall: ', 0.25)
# (1, 'Question: ', 314, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.05128205128205128, ' recall: ', 0.16666666666666666)
# (1, 'Question: ', 315, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 316, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 317, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 318, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 319, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 320, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 321, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 322, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 323, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.6666666666666666, ' recall: ', 1.0)
# (1, 'Question: ', 324, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 325, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.2, ' recall: ', 0.16666666666666666)
# (1, 'Question: ', 326, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 327, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.33333333333333337, ' recall: ', 0.3076923076923077)
# (1, 'Question: ', 328, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 329, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.3, ' recall: ', 0.3)
# (1, 'Question: ', 330, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 331, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 332, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 333, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 334, ' scores are -> ', 'exact_match: ', True, ' f1: ', 1.0, ' recall: ', 1.0)
# (1, 'Question: ', 335, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 336, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 337, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 338, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.9090909090909091, ' recall: ', 0.8333333333333334)
# (1, 'Question: ', 339, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.4, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 340, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 341, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5, ' recall: ', 0.5)
# (1, 'Question: ', 342, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 343, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.6666666666666666, ' recall: ', 0.5)
# (1, 'Question: ', 344, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 345, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 346, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 347, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 348, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.5, ' recall: ', 0.5)
# (1, 'Question: ', 349, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 350, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 351, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.6666666666666666, ' recall: ', 0.6666666666666666)
# (1, 'Question: ', 352, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 353, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.22222222222222224, ' recall: ', 0.2)
# (1, 'Question: ', 354, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 355, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 356, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 357, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 358, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 359, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 360, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 361, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 362, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 363, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 364, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 365, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 366, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 367, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 368, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 369, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 370, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 371, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 372, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 373, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 374, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 375, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 376, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 377, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 378, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 379, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 380, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 381, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 382, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 383, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.3333333333333333, ' recall: ', 0.3333333333333333)
# (1, 'Question: ', 384, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 385, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 386, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 387, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 388, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 389, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 390, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 391, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 392, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 393, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 394, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 395, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 396, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 397, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 398, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 399, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 400, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 401, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 402, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 403, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 404, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 405, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 406, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 407, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 408, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 409, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 410, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 411, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 412, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 413, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 414, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 415, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 416, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 417, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 418, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 419, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 420, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 421, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 422, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 423, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 424, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 425, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 426, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0.25, ' recall: ', 0.16666666666666666)
# (1, 'Question: ', 427, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 428, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 429, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 430, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 431, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 432, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 433, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 434, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 435, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 436, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 437, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 438, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 439, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 440, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 441, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 442, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 443, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 444, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 445, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 446, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 447, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 448, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 449, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 450, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 451, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 452, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 453, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 454, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 455, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 456, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 457, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 458, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 459, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 460, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 461, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 462, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 463, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 464, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
# (1, 'Question: ', 465, ' scores are -> ', 'exact_match: ', False, ' f1: ', 0, ' recall: ', 0.0)
